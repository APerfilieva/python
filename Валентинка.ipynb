# %%
from matplotlib import pyplot as plt   
from matplotlib import style   
style.use('ggplot')   
   
x = [8,8.5,9,10,10.5,11,11,10.5, 10, 9.5, 9, 8.5, 8,7.5,7,6, 5.5, 5,5,5.5, 6, 6.5, 7, 7.5]   
y = [5,9,10,10,9.5,7,5,2, 0, -2, -4, -6, -8,9,10,10, 9.5,7,5,2, 0, -2, -4, -6]   
   
plt.scatter(x, y)   
      
plt.title('Сашучек, я тебя люблю!')   
plt.ylabel('Y axis')   
plt.xlabel('X axis')   
   
plt.show()
